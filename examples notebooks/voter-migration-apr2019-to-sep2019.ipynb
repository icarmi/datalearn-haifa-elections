# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cvxpy as cvx
import matplotlib.pyplot as plt

from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /kaggle/input/israeli-elections-2015-2013/israeli_elections_results_1996_to_2015.csv
# /kaggle/input/israeli-elections-2015-2013/votes per settlement 2015 - hebrew.csv
# /kaggle/input/israeli-elections-2015-2013/votes per settlement 2019b.csv
# /kaggle/input/israeli-elections-2015-2013/votes per booth 2019a.csv
# /kaggle/input/israeli-elections-2015-2013/votes per settlement 2019a.csv
# /kaggle/input/israeli-elections-2015-2013/votes per settlement 2019 - hebrew.csv
# /kaggle/input/israeli-elections-2015-2013/votes per booth 2019b.csv

# %%
import pandas as pd
import numpy as np
import os
import cvxpy as cvx
from matplotlib import pyplot as plt

DATA_PATH = '/kaggle/input/israeli-elections-2015-2013/'
df_apr_raw = pd.read_csv(os.path.join(DATA_PATH, r'votes per settlement 2019a.csv'), encoding = 'iso-8859-8', index_col='שם ישוב').sort_index()
df_sep_raw = pd.read_csv(os.path.join(DATA_PATH, r'votes per settlement 2019b.csv'), encoding = 'iso-8859-8', index_col='שם ישוב').sort_index()

df_apr = df_apr_raw.drop(df_apr_raw.index.difference(df_sep_raw.index))
df_sep = df_sep_raw.drop(df_sep_raw.index.difference(df_apr_raw.index))
df_sep.drop('סמל ועדה', axis=1, inplace=True) # new column added in Sep 2019

df_sep = df_sep[df_sep.columns[5:]] # removing "metadata" columns
df_apr = df_apr[df_apr.columns[5:]]

print("{} votes in April 2019, vs {} in September".format(df_apr_raw['כשרים']['מעטפות חיצוניות'], 
                                                                df_sep_raw['כשרים']['מעטפות חיצוניות']))
# Out:
# 238822 votes in April 2019, vs 277212 in September

# %%
def party_votes(df, year):
    return df.sum().div(df.sum().sum()).sort_values(ascending=False).rename('party votes '+str(year))

parties_apr, parties_sep = party_votes(df_apr, 'Apr'), party_votes(df_sep, 'Sep')

# %%
thresh = 0.01
def threshold_parties(series, threshold):
    s = series[series>threshold]
    year = s.name.split(' ')[-1]
    print("in {}, the following {} parties (out of {}) got {:.3} of votes: \n{}\n".format(year, len(s), len(series), 
                                                                                sum(s), s.index.values))
    return s

parties_apr, parties_sep = threshold_parties(parties_apr, thresh), threshold_parties(parties_sep, thresh)


df_apr.loc[:,'אחר'] = df_apr[df_apr.columns.difference(parties_apr.index)].sum(axis=1)
df_apr = df_apr[parties_apr.index.append(pd.Index(['אחר']))]
df_sep.loc[:,'אחר'] = df_sep[df_sep.columns.difference(parties_sep.index)].sum(axis=1)
df_sep = df_sep[parties_sep.index.append(pd.Index(['אחר']))]
# Out:
# in Apr, the following 14 parties (out of 43) got 0.992 of votes:
# ['מחל' 'פה' 'שס' 'ג' 'ום' 'אמת' 'ל' 'טב' 'מרצ' 'כ' 'דעם' 'נ' 'ז' 'נר']
#
# in Sep, the following 10 parties (out of 32) got 0.99 of votes:
# ['פה' 'מחל' 'ודעם' 'שס' 'ל' 'ג' 'טב' 'אמת' 'מרצ' 'כף']

# %%
df_apr.loc[:,'לא הצביעו'] = (df_sep.sum(axis=1)-df_apr.sum(axis=1)).clip(lower=0) # "added" voters (new voters + increased turnout)
df_sep.loc[:,'לא הצביעו'] = (df_apr.sum(axis=1)-df_sep.sum(axis=1)).clip(lower=0) # "removed" voteres (decreased turnout)

parties_apr, parties_sep = party_votes(df_apr, 'Apr'), party_votes(df_sep, 'Sep')
parties_apr.to_frame('April').join(parties_sep.rename('September'), how='outer').round(2)
# Out:
#            April  September
# אחר         0.01       0.01
# אמת         0.04       0.05
# ג           0.06       0.06
# דעם         0.03        NaN
# ודעם         NaN       0.11
# ום          0.04        NaN
# ז           0.03        NaN
# טב          0.04       0.06
# כ           0.03        NaN
# כף           NaN       0.02
# ל           0.04       0.07
# לא הצביעו   0.04       0.01
# מחל         0.26       0.25
# מרצ         0.04       0.04
# נ           0.03        NaN
# נר          0.02        NaN
# פה          0.25       0.26
# שס          0.06       0.07

# %%
df_apr.head()
# Out:
#                     מחל   פה  שס  ג    ום  אמת    ל  טב  מרצ    כ  דעם  נ  ז  \
# שם ישוב
# אבו ג'ווייעד (שבט)    2   50   0  0    13    5    0   0   10    1  175  3  1
# אבו גוש             201  334  30  2   490   35   10  11  313   14  368  1  2
# אבו סנאן            142  701  62  6  2152   60  183   4  187  515  592  7  2
# אבו עבדון (שבט)       0    0   0  0     3    0    0   0    5    0    2  0  0
# אבו קורינאת (שבט)     8   91   2  0    34    8    2   3   22    1  433  1  0
#
#                     נר  אחר  לא הצביעו
# שם ישוב
# אבו ג'ווייעד (שבט)   0   10        263
# אבו גוש              6   26        563
# אבו סנאן             3  147        854
# אבו עבדון (שבט)      0    2         34
# אבו קורינאת (שבט)    1   23        580

# %%
df_sep.head()
# Out:
#                      פה  מחל  ודעם   שס    ל  ג  טב  אמת  מרצ  כף  אחר  \
# שם ישוב
# אבו ג'ווייעד (שבט)   22    3   498    0    0  1   0    3    0   0    6
# אבו גוש             295  115  1732   52   12  5   2   40   82   4   67
# אבו סנאן            802  224  3759  227  381  4   6   88   55   3   68
# אבו עבדון (שבט)       1    0    45    0    0  0   0    0    0   0    0
# אבו קורינאת (שבט)    60   10  1091    5    2  0   2   15    6   0   18
#
#                     לא הצביעו
# שם ישוב
# אבו ג'ווייעד (שבט)          0
# אבו גוש                     0
# אבו סנאן                    0
# אבו עבדון (שבט)             0
# אבו קורינאת (שבט)           0

# %%
coefficients = cvx.Variable(shape=(df_apr.shape[1], df_sep.shape[1]))
constraints=[0<=coefficients, coefficients<=1, cvx.sum(coefficients,axis=1)==1]

mse = cvx.sum_squares(df_apr.values*coefficients-df_sep.values) 
mse = mse / df_apr.shape[0]
objective=cvx.Minimize(mse)
prob=cvx.Problem(objective, constraints)

mse = prob.solve(verbose = True, solver='OSQP')
coeff_mat = coefficients.value
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.0  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2019
# -----------------------------------------------------------------
# problem:  variables n = 14736, constraints m = 14944
#           nnz(P) + nnz(A) = 206712
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.14e+05   5.02e+08   1.00e-01   2.20e-01s
#  200   3.7636e+05   2.08e-01   7.03e+01   3.41e+00   5.20e-01s
#  400   4.1624e+05   5.37e-02   1.31e+01   3.41e+00   8.06e-01s
#  600   4.2895e+05   1.85e-02   4.69e+00   3.41e+00   1.10e+00s
#  800   4.3361e+05   6.96e-03   1.49e+00   3.41e+00   1.38e+00s
# 1000   4.3526e+05   2.58e-03   4.97e-01   3.41e+00   1.67e+00s
# 1200   4.3584e+05   9.32e-04   1.69e-01   3.41e+00   1.96e+00s
# 1400   4.3604e+05   3.24e-04   6.10e-02   3.41e+00   2.24e+00s
# 1600   4.3611e+05   1.45e-04   2.66e-02   3.41e+00   2.54e+00s
# 1800   4.3614e+05   7.74e-05   1.50e-02   3.41e+00   2.83e+00s
# 2000   4.3615e+05   4.16e-05   8.37e-03   3.41e+00   3.13e+00s
# 2200   4.3616e+05   2.25e-05   4.66e-03   3.41e+00   3.42e+00s
# 2400   4.3616e+05   1.23e-05   2.58e-03   3.41e+00   3.71e+00s
# 2600   4.3616e+05   6.72e-06   1.43e-03   3.41e+00   4.00e+00s
# 2800   4.3616e+05   3.69e-06   7.91e-04   3.41e+00   4.29e+00s
# 3000   4.3616e+05   2.03e-06   4.37e-04   3.41e+00   4.58e+00s
# 3200   4.3616e+05   1.12e-06   2.41e-04   3.41e+00   4.86e+00s
# 3375   4.3616e+05   6.63e-07   1.44e-04   3.41e+00   5.11e+00s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 3375
# optimal objective:    436158.8825
# run time:             5.32e+00s
# optimal rho estimate: 6.85e+00

# %%
naive_estimation = df_sep.apply(lambda x: x.sum() * parties_sep, axis=1)
naive_mse = naive_estimation.subtract(df_sep).apply(np.square).sum(axis=1).mean()
print("the R2 score of our solution (calculated manually) is {:.3}".format(1 - mse / naive_mse))
# Out:
# the R2 score of our solution (calculated manually) is 0.978

# %%
def display_df(_df): # TThanks, Dean Langsam!
    _display_df = _df.join(pd.DataFrame(columns=_df.index.difference(_df.columns)))
    _display_df = _display_df.append(pd.DataFrame(index=_display_df.columns.difference(_display_df.index), data=0, columns=_display_df.columns)).fillna(0)
    _display_df = _display_df.sort_index(axis=0).sort_index(axis=1).T.round(1)
    return _display_df.style.background_gradient(cmap=plt.get_cmap('Accent_r'))

# %%
transfer_matrix = pd.DataFrame(data=coefficients.value, 
                               index=df_apr.columns, columns = df_sep.columns).applymap(lambda x: round(x,3))
display_df(transfer_matrix)
# Out:
# <style  type="text/css" >
#     #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col0 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col7 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col11 {
#             background-color:  #f0027f;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col15 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow0_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col1 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col7 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col11 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col15 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow1_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col2 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col7 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col11 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col15 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow2_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_26fb4948_094d_11ea_af24_7561e0c2e66brow3_col5 {
#             background-color:  #666666;

# %%
vote_transfers = (transfer_matrix.T * parties_apr * 120).sort_index(axis=1).T
display_df(vote_transfers)
# Out:
# <style  type="text/css" >
#     #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col0 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col7 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col11 {
#             background-color:  #f0027f;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col15 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow0_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col1 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col7 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col11 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col15 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow1_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col2 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col5 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col6 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col7 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col8 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col9 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col10 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col11 {
#             background-color:  #bf5b17;
#             color:  #000000;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col12 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col13 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col14 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col15 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col16 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow2_col17 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_2723d4ee_094d_11ea_af24_7561e0c2e66brow3_col5 {
#             background-color:  #666666;

# %%
transfer_threshold=1
links=np.where(vote_transfers > transfer_threshold)

# labels_english = ['other', 'Avoda_15', 'Joint', 'Lapid','Kahlon_15', 'Bait',
#                   'Shas_15', 'Liberman_15', 'Gimel_15' ,'Meretz_15', 'Yachad', 'other_15', 'no_15',
#                  'Likud_19', 'Kaholavan', 'Shas_19', 'Gimel_19', 'Hadash', 'Avoda_19', 'Liberman_19',
#                   'UYamin', 'Meretz_19', 'Kahlon_19', 'Raam-Balad', 'NYamin','Zehut','other_19','no_19']

labels_hebrew = vote_transfers.index.to_list()+vote_transfers.columns.to_list()
labels_hebrew = [x[::-1] for x in labels_hebrew]

data = dict(
    type='sankey',
    node = dict(pad = 15, 
                thickness = 20, 
                line = dict(color = "black",width = 0.5),
                color='black',
                label=labels_hebrew),
    link = dict(source=links[0],
                target=links[1]+max(links[0])+1,
                value=[vote_transfers.values[f[0],f[1]] for f in zip(links[0],links[1])]),
    orientation = 'h'
)

layout =  dict(
    title = "Shift in votes between parties, from Apr 2019 to Sep 2019 elections",
    font = dict(size = 14)
)

fig = dict(data=[data], layout=layout)
iplot(fig,validate=False)
# Out:
# <div>
#
#
#             <div id="8500573e-e2b3-4271-b194-d142b99f838d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8500573e-e2b3-4271-b194-d142b99f838d")) {
#                     Plotly.newPlot(
#                         '8500573e-e2b3-4271-b194-d142b99f838d',
#                         [{"link": {"source": [1, 1, 2, 3, 4, 5, 5, 6, 6, 7, 7, 8, 9, 10, 10, 11, 12, 13, 14, 15], "target": [23, 24, 21, 18, 18, 16, 17, 22, 25, 16, 20, 20, 16, 17, 19, 24, 22, 23, 16, 19], "value": [2.5114877218536615, 2.583244513906623, 6.655325282415159, 3.858549917087793, 5.1953959497123865, 1.2200455731774924, 1.4577167887315496, 2.4587156743574665, 1.218667769029353, 1.4646401337159374, 1.9200324441990442, 4.646422912909841, 1.1428681558261575, 26.949728814750472, 1.745607434591792, 3.937607916241325, 3.718056866426633, 1.8096611465720855, 27.607239031338334, 6.936451581352554]}, "node": {"color": "black", "label": ["\u05e8\u05d7\u05d0", "\u05ea\u05de\u05d0", "\u05d2", "\u05dd\u05e2\u05d3", "\u05dd\u05d5", "\u05d6", "\u05d1\u05d8", "\u05db", "\u05dc", "\u05d5\u05e2\u05d9\u05d1\u05e6\u05d4 \u05d0\u05dc", "\u05dc\u05d7\u05de", "\u05e6\u05e8\u05de", "\u05e0", "\u05e8\u05e0", "\u05d4\u05e4", "\u05e1\u05e9", "\u05d4\u05e4", "\u05dc\u05d7\u05de", "\u05dd\u05e2\u05d3\u05d5", "\u05e1\u05e9", "\u05dc", "\u05d2", "\u05d1\u05d8", "\u05ea\u05de\u05d0", "\u05e6\u05e8\u05de", "\u05e3\u05db", "\u05e8\u05d7\u05d0", "\u05d5\u05e2\u05d9\u05d1\u05e6\u05d4 \u05d0\u05dc"], "line": {"color": "black", "width": 0.5}, "pad": 15, "thickness": 20}, "orientation": "h", "type": "sankey"}],
#                         {"font": {"size": 14}, "title": "Shift in votes between parties, from Apr 2019 to Sep 2019 elections"},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8500573e-e2b3-4271-b194-d142b99f838d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
